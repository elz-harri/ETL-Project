# %%
from splinter import Browser
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import pymongo
import pandas as pd
import requests
from sqlalchemy import create_engine

# %%
# open browser
browser = Browser('chrome')
url = 'http://quotes.toscrape.com/'

# %%
# get author born, 
def quote_author(url):
    author_info = {}
    
    # request author html data
    authorPage = requests.get(url).text
    
    # parse response
    author = BeautifulSoup(authorPage, 'html.parser')
    
    # find author details
    author_info['name'] = author.find('h3', class_ = 'author-title').text
    author_info['birthday'] = author.find('span', class_ = 'author-born-date').text
    author_info['location'] = author.find('span', class_ = 'author-born-location').text
    author_info['description'] = author.find('div', class_ = 'author-description').text.strip()
    
    return author_info

# %%
# get tags
def get_tags(quote):
    tagList = []
    
    quoteTags = quote.find_all('a', class_='tag')
    
    for tag in quoteTags:
        tagList.append(tag.text)
    
    return tagList

# %%
# get quote info
def quote_data(quote):
    quote_info = {}
    quote_info['quote_text'] = quote.find('span', class_='text').text
    auth_url = urljoin(url, quote.find('a')['href'])
    
    # get author data
    quote_info['author'] = quote_author(auth_url)
    
    # get tag data
    quote_info['tag'] = get_tags(quote)
    
    return quote_info

# %%
# get list of quote boxes
def get_quoteList(pageNumber):
    quoteList = []
    
    # get html data from current page
    html = browser.html
    
    # use BeautifulSoup to parse html data
    soup = BeautifulSoup(html, 'html.parser')
    
    # find all quote blocks
    quotes = soup.find_all('div', class_='quote')
    
    # initialize quote ids
    quoteID = (pageNumber - 1) * 10
    
    # for each quote in the list retuned
    for quote in quotes:
        # increment quote id
        quoteID += 1
        
        # get all quote data returned as a dictionary
        quote_dic = quote_data(quote)
        quote_dic['_id'] = quoteID
        
        quoteList.append(quote_dic)
    
#         quoteList[0]: {_id: 1,
#                         quote_text: ,
#                         author:{name:
#                                 birthday:      
#                                 born:
#                                 description:}
#                         tags: []
#                       }
    
    return quoteList

# %%
# scrape everything
def scrap_everything(url):
    all_quotes = []
    
    first_iterations = True
    nextPage = True
    pageNumber = 1
    
    while nextPage == True:
        
        # if this is the first time through the while loop, navigate to url 
        if first_iterations == True:
            browser.visit(url)
            first_iterations = False
        else:
            pass
        
        # get all quote data from the page
        print(f'Scraping Page {pageNumber}')
        currentList = get_quoteList(pageNumber)
        all_quotes =  all_quotes + currentList
        
        try:
            browser.links.find_by_partial_text('Next').click()
            pageNumber += 1  
        except:
            print("Scraping Complete")
            nextPage = False
    
    return all_quotes

# %%
data = scrap_everything(url)
# Out:
# Scraping Page 1
# Scraping Page 2
# Scraping Page 3
# Scraping Page 4
# Scraping Page 5
# Scraping Page 6
# Scraping Page 7
# Scraping Page 8
# Scraping Page 9
# Scraping Page 10
# Scraping Complete

# %%
browser.quit()

# %% [markdown]
# ### Send data to MongoDB

# %%
# Initialize PyMongo to work with MongoDBs
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
# Define database and collection
db = client.quoteslist_db
collection = db.items

# %%
# Dictionary to be inserted as a MongoDB document
collection.insert_many(data)

# %% [markdown]
# ### Move data from  MongoDB to put into postgres

# %%
# mongo_data = db.mongo_data
mongo_df = pd.DataFrame(list(collection.find()))
mongo_df
# Out:
#     _id                                         quote_text  \
# 0     1  “The world as we have created it is a process ...
# 1     2  “It is our choices, Harry, that show what we t...
# 2     3  “There are only two ways to live your life. On...
# 3     4  “The person, be it gentleman or lady, who has ...
# 4     5  “Imperfection is beauty, madness is genius and...
# ..  ...                                                ...
# 95   96  “You never really understand a person until yo...
# 96   97  “You have to write the book that wants to be w...
# 97   98  “Never tell the truth to people who are not wo...
# 98   99        “A person's a person, no matter how small.”
# 99  100  “... a mind needs books as a sword needs a whe...
#
#                                                author  \
# 0   {'name': 'Albert Einstein', 'birthday': 'March...
# 1   {'name': 'J.K. Rowling', 'birthday': 'July 31,...
# 2   {'name': 'Albert Einstein', 'birthday': 'March...
# 3   {'name': 'Jane Austen', 'birthday': 'December ...
# 4   {'name': 'Marilyn Monroe', 'birthday': 'June 0...
# ..                                                ...
# 95  {'name': 'Harper Lee', 'birthday': 'April 28, ...
# 96  {'name': 'Madeleine L'Engle', 'birthday': 'Nov...
# 97  {'name': 'Mark Twain', 'birthday': 'November 3...
# 98  {'name': 'Dr. Seuss', 'birthday': 'March 02, 1...
# 99  {'name': 'George R.R. Martin', 'birthday': 'Se...
#
#                                                   tag
# 0            [change, deep-thoughts, thinking, world]
# 1                                [abilities, choices]
# 2      [inspirational, life, live, miracle, miracles]
# 3                  [aliteracy, books, classic, humor]
# 4                        [be-yourself, inspirational]
# ..                                                ...
# 95                              [better-life-empathy]
# 96  [books, children, difficult, grown-ups, write,...
# 97                                            [truth]
# 98                                    [inspirational]
# 99                                      [books, mind]
#
# [100 rows x 4 columns]

# %%
# then we need to manipulate the Dataframe data to look how we want it
#  table withe _id & Text & Author name
quote_df = mongo_df[['_id','quote_text','author']].set_index(['_id'])
quote_df
# Out:
#                                             quote_text  \
# _id
# 1    “The world as we have created it is a process ...
# 2    “It is our choices, Harry, that show what we t...
# 3    “There are only two ways to live your life. On...
# 4    “The person, be it gentleman or lady, who has ...
# 5    “Imperfection is beauty, madness is genius and...
# ..                                                 ...
# 96   “You never really understand a person until yo...
# 97   “You have to write the book that wants to be w...
# 98   “Never tell the truth to people who are not wo...
# 99         “A person's a person, no matter how small.”
# 100  “... a mind needs books as a sword needs a whe...
#
#                                                 author
# _id
# 1    {'name': 'Albert Einstein', 'birthday': 'March...
# 2    {'name': 'J.K. Rowling', 'birthday': 'July 31,...
# 3    {'name': 'Albert Einstein', 'birthday': 'March...
# 4    {'name': 'Jane Austen', 'birthday': 'December ...
# 5    {'name': 'Marilyn Monroe', 'birthday': 'June 0...
# ..                                                 ...
# 96   {'name': 'Harper Lee', 'birthday': 'April 28, ...
# 97   {'name': 'Madeleine L'Engle', 'birthday': 'Nov...
# 98   {'name': 'Mark Twain', 'birthday': 'November 3...
# 99   {'name': 'Dr. Seuss', 'birthday': 'March 02, 1...
# 100  {'name': 'George R.R. Martin', 'birthday': 'Se...
#
# [100 rows x 2 columns]

# %%
# create author series
author_df = mongo_df[['author']]
author_df
# Out:
#                                                author
# 0   {'name': 'Albert Einstein', 'birthday': 'March...
# 1   {'name': 'J.K. Rowling', 'birthday': 'July 31,...
# 2   {'name': 'Albert Einstein', 'birthday': 'March...
# 3   {'name': 'Jane Austen', 'birthday': 'December ...
# 4   {'name': 'Marilyn Monroe', 'birthday': 'June 0...
# ..                                                ...
# 95  {'name': 'Harper Lee', 'birthday': 'April 28, ...
# 96  {'name': 'Madeleine L'Engle', 'birthday': 'Nov...
# 97  {'name': 'Mark Twain', 'birthday': 'November 3...
# 98  {'name': 'Dr. Seuss', 'birthday': 'March 02, 1...
# 99  {'name': 'George R.R. Martin', 'birthday': 'Se...
#
# [100 rows x 1 columns]

# %%
# # create author series
# from collections import OrderedDict
# # iterate over the list of MongoDB dict documents
# for author, data in enumerate(author_df):
#         data = OrderedDict(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-d4580c95287a> in <module>
#       3 # iterate over the list of MongoDB dict documents
#       4 for author, data in enumerate(author_df):
# ----> 5         data = OrderedDict(data)
#       6
#
# ValueError: need more than 1 value to unpack

# %%
data

# %%
#  table withe _id & Text & Author name
# table with _id and Tag
# tabel with author name, data, location, description

# %%
#  table withe _id & Text & Author name
# table with _id and Tag
# tabel with author name, data, location, description

# %%
#  table withe _id & Text & Author name
# table with _id and Tag
# tabel with author name, data, location, description
